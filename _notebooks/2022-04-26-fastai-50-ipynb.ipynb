# %% [markdown]
# # Practical Deep Learning for Coders Course - Lesson 0
#
# > "This blog-post series captures my weekly notes while I attend the [fastaiv5 course conducted by University of Queensland with fast.ai](https://itee.uq.edu.au/event/2022/practical-deep-learning-coders-uq-fastai). So without further adieu, let's go!"
#
# - toc: true
# - branch: master
# - badges: true
# - hide_binder_badge: true
# - comments: true
# - author: Kurian Benoy
# - categories: [fastai, fastbook]
# - image: images/articles/fastbook.jpg
# - hide: false
# - search_exclude: false

# %% [markdown]
# Last week I enrolled for the live cohort of Deep Learning For Coders
# with fastai Couse which is going to be taken by [Jeremy Howard](https://www.linkedin.com/in/howardjeremy). It's' a previlege
# at the same time, a dream come true moment for me, as a fastai student who took
# some part of fast.ai from the year 2018.
#
# The fastai course has seen a lot of success stories over the years. Amazing folks
# like Aman Arora, Even Oldridge, Sanyam Bhutani,Radek Osmulski, Jason Antic, Wayde Gilliam, Zach Mueller ... While there are lot of hidden gems whom may not be so well know in community as well like [Bhuvana who
# shared her journey in Pycon India 2019](https://youtu.be/TGIEOSrEyD8). The way this course
# has democratized AI & ML is simply amazing.
#
# Today [Radek Osmulski](https://twitter.com/radekosmulski) joined NVIDIA AI.
#
# > twitter: https://twitter.com/radekosmulski/status/1518786955278192640

# %% [markdown]
# It was Radek who had posted in fastai forums few years back on [how he will approach taking the fastai course](https://forums.fast.ai/t/what-i-will-focus-on-to-succeed-in-this-course/6926). Inspired by that I am creating this action list items on things which I am planning to achieve during duration of this course.
#
# **I will do following:**
#
# 1. Try out every notebook given by Jeremy during class and writes in Kaggle
# 2. Write blogpost every week with lesson summary and occasionally on new things I learning during course.
# 3. Build some hugging face spaces using fastai
# 4. Challenge myself to complete the existing project I am doing on [IPL Commentary Summarizer](https://github.com/kurianbenoy/chaloRR) and learn NLP extensively.
# 5. Attend the [delft-fast-ai-study-group sessions](https://www.meetup.com/delft-fast-ai-study-group/events/285269418/) atleast for five weeks.
# 6. Go to sleep before midnight
# 7. Dream and breath pytorch
#
# **Extra Credits:**
#
# 1. Participate in [NLP competition provided by jeremy link](https://www.kaggle.com/competitions/us-patent-phrase-to-phrase-matching/overview).
# 2. Frequent in fast.ai forums and discord group
# 3. Take a look at notebooks in Transformer Book if you cover NLP extensively during class
# 4. Try to read Pytorch book
# 5. Complete all the college assignments in Pytorch
#
# **I won't do:**
#
# 2. Be active in twitter during course
# 3. Read EDA notebooks
# 4. Won't write any notebooks in tensorflow :)
# 5. Won't participate in any other kaggle comps during course period.
# 6. I will be not attending Real Python community meetups, unless I have a very compelling doubt.
#
# With that I am winding for today.
